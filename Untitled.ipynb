# %%
import pandas as pd
# from tabula import read_pdf
# df = read_pdf('2014 Union December.pdf')
df = pd.read_excel('Berkeley_heights.xlsx')
# df2 = read_pdf('Area Market Analysis Report.pdf')

# %%
df['Town']= "Berkeley_heights"

# %%
df['County'] = 'Union'

# %%
df['State'] = 'NJ'

# %%
df[['Town','County','State']]
# Out:
#                  Town County State
# 0    Berkeley_heights  Union    NJ
# 1    Berkeley_heights  Union    NJ
# 2    Berkeley_heights  Union    NJ
# 3    Berkeley_heights  Union    NJ
# 4    Berkeley_heights  Union    NJ
# ..                ...    ...   ...
# 115  Berkeley_heights  Union    NJ
# 116  Berkeley_heights  Union    NJ
# 117  Berkeley_heights  Union    NJ
# 118  Berkeley_heights  Union    NJ
# 119  Berkeley_heights  Union    NJ
#
# [120 rows x 3 columns]

# %%
df.to_csv('berkeley_heights.csv')

# %%
df.columns
# Out:
# Index(['Date', 'ActiveNum', 'AvLP', 'AvMP', 'NewLnum', 'NewLAVLP', 'NewLAVMP',
#        'UCNewNum', 'UCAVLP', 'UCAVMP', 'UCAvDOM', 'SoldNum', 'SoldAVLP',
#        'SoldAVMP', 'SoldAVDOM', 'SP/LP', 'SP/OLP', 'Town', 'County', 'State'],
#       dtype='object')

# %%
df.tail(10)
# Out:
#           Date ActiveNum       AvLP       AvMP NewLnum   NewLAVLP   NewLAVMP  \
# 110  Oct,2009        85   $663,335   $549,000      19   $541,989   $469,000
# 111  Sep,2009        83   $675,420   $569,000      24   $580,167   $499,900
# 112  Aug,2009        87   $705,774   $639,000      13   $656,292   $650,000
# 113  Jul,2009        99   $693,513   $599,000      16   $519,925   $519,000
# 114  Jun,2009       104   $709,160   $599,999      20   $558,530   $525,000
# 115  May,2009       101   $718,246   $625,000      20   $621,190   $599,000
# 116  Apr,2009        98   $715,564   $625,000      26   $686,354   $589,000
# 117  Mar,2009        91   $710,112   $625,000      24   $620,263   $569,900
# 118  Feb,2009        80   $711,117   $599,900      19   $722,774   $639,900
# 119  Jan,2009        78   $679,364   $575,000      16   $709,306   $629,000
#
#     UCNewNum     UCAVLP     UCAVMP UCAvDOM SoldNum   SoldAVLP   SoldAVMP  \
# ...
